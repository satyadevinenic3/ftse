# %%
import zipfile
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
zip_path = "data/timeseries_data.zip"  
extract_to = "data/timeseries_data_dump" 

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %% [markdown]
# ### Summary

# %%
csv_dir = "data/timeseries_data_dump/timeseries_data/"
output_csv = "data_summary.csv"

columns = ["CSV File Name", "Shape", "Num Columns", "Num Numerical", "Num Textual", "NULLS %", "Zeros"]
pd.DataFrame(columns=columns).to_csv(output_csv, index=False)

def Nulls(df):
    return {col: f"{df[col].isnull().mean() * 100:.1f}%" for col in df.columns}

def Zeros(df):
    return {
        col: f"{(df[col] == 0).mean() * 100:.1f}%" if pd.api.types.is_numeric_dtype(df[col]) else "0.0%"
        for col in df.columns
    }

for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        file_path = os.path.join(csv_dir, file)
        df = pd.read_csv(file_path)
        
        num_columns = df.shape[1]
        num_rows = df.shape[0]
        
        generic_col_map = {col: f"col{i+1}" for i, col in enumerate(df.columns)}
        
        numerical_cols = df.select_dtypes(include=[np.number])
        textual_cols = df.select_dtypes(include=["object", "string", "category"])
        
        num_numerical = len(numerical_cols.columns)
        num_textual = len(textual_cols.columns)
        
        nulls_dict = Nulls(df)
        zeros_dict = Zeros(df)
        
        nulls_str = ", ".join([f"{generic_col_map[k]}: {v}" for k, v in nulls_dict.items()])
        zeros_str = ", ".join([f"{generic_col_map[k]}: {v}" for k, v in zeros_dict.items()])
        
        row = {
            "CSV File Name": file,
            "Shape": f"{num_rows} x {num_columns}",
            "Num Columns": num_columns,
            "Num Numerical": num_numerical,
            "Num Textual": num_textual,
            "NULLS %": nulls_str,
            "Zeros": zeros_str
        }
        
        print(f"Shape: {row['Shape']}")
        print(f"Num Columns: {row['Num Columns']}, Num Numerical: {row['Num Numerical']}, Num Textual: {row['Num Textual']}")
        print("NULLs %:", row["NULLS %"])
        print("Zeros %:", row["Zeros"])
        
        # Append real row to CSV
        pd.DataFrame([row]).to_csv(output_csv, mode='a', header=False, index=False)
# Out:
# Shape: 177 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 70.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 72.2%, col3: 0.0%, col4: 0.0%
# Shape: 228 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 73.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.1%, col3: 0.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 75.4%, col3: 0.0%, col4: 0.0%
# Shape: 185 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 81.1%
# Zeros %: col1: 0.0%, col2: 62.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 34.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 58.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 52.4%, col3: 5.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.3%
# Zeros %: col1: 0.0%, col2: 30.2%, col3: 2.0%, col4: 0.0%
# Shape: 108 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 76.9%
# Zeros %: col1: 0.0%, col2: 33.3%, col3: 0.9%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.8%
# Zeros %: col1: 0.0%, col2: 30.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.4%, col3: 1.6%, col4: 0.0%
# Shape: 205 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 49.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.0%
# Zeros %: col1: 0.0%, col2: 61.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 82.9%, col3: 0.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 25.0%, col3: 3.2%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 93.3%, col3: 0.0%, col4: 0.0%
# Shape: 149 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 49.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.7%, col3: 0.0%, col4: 0.0%
# Shape: 146 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 18.5%, col3: 0.0%, col4: 0.0%
# Shape: 92 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 92.4%
# Zeros %: col1: 0.0%, col2: 82.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 94.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.9%, col3: 0.0%, col4: 0.0%
# Shape: 201 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 82.6%
# Zeros %: col1: 0.0%, col2: 72.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 83.3%, col3: 0.0%, col4: 0.0%
# Shape: 125 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 0.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 50.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 59.9%, col3: 0.0%, col4: 0.0%
# Shape: 181 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 80.1%
# Zeros %: col1: 0.0%, col2: 89.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 56.0%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.7%
# Zeros %: col1: 0.0%, col2: 60.2%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 70.0%
# Zeros %: col1: 0.0%, col2: 21.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.5%, col3: 21.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.3%
# Zeros %: col1: 0.0%, col2: 79.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 77.4%, col3: 5.2%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.5%
# Zeros %: col1: 0.0%, col2: 87.3%, col3: 0.0%, col4: 0.0%
# Shape: 234 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 60.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.1%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.7%
# Zeros %: col1: 0.0%, col2: 42.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 66.7%, col3: 4.4%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 71.0%, col3: 0.0%, col4: 0.0%
# Shape: 163 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.4%, col3: 0.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.9%
# Zeros %: col1: 0.0%, col2: 38.4%, col3: 0.0%, col4: 0.0%
# Shape: 251 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.8%, col3: 0.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 82.8%
# Zeros %: col1: 0.0%, col2: 62.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 48.0%, col3: 1.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 33.7%, col3: 6.0%, col4: 0.0%
# Shape: 152 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 57.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 61.1%, col3: 0.0%, col4: 0.0%
# Shape: 154 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 56.0%, col3: 3.6%, col4: 0.0%
# Shape: 201 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.7%, col3: 64.7%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 71.8%, col3: 2.8%, col4: 0.0%
# Shape: 130 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 80.0%, col3: 0.0%, col4: 0.0%
# Shape: 247 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.1%, col3: 0.0%, col4: 0.0%
# Shape: 92 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 45.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.1%
# Zeros %: col1: 0.0%, col2: 64.7%, col3: 0.4%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.5%, col3: 0.0%, col4: 0.0%
# Shape: 93 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 1.1%, col3: 0.0%, col4: 0.0%
# Shape: 92 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.0%
# Zeros %: col1: 0.0%, col2: 50.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 53.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 62.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.1%
# Zeros %: col1: 0.0%, col2: 21.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 54.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.5%
# Zeros %: col1: 0.0%, col2: 82.9%, col3: 6.3%, col4: 0.0%
# Shape: 170 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.2%, col3: 0.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.9%
# Zeros %: col1: 0.0%, col2: 27.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 52.4%, col3: 1.2%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.9%, col3: 0.0%, col4: 0.0%
# Shape: 91 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 48.4%, col3: 0.0%, col4: 0.0%
# Shape: 96 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.5%
# Zeros %: col1: 0.0%, col2: 45.8%, col3: 0.0%, col4: 0.0%
# Shape: 251 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 46.8%, col3: 3.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 36.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.3%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 80.0%, col3: 8.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 95.6%
# Zeros %: col1: 0.0%, col2: 97.6%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.7%
# Zeros %: col1: 0.0%, col2: 39.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 78.6%, col3: 0.0%, col4: 0.0%
# Shape: 249 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 84.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 93.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.5%, col3: 0.0%, col4: 0.0%
# Shape: 187 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.8%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 83.0%
# Zeros %: col1: 0.0%, col2: 41.0%, col3: 8.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 86.9%, col3: 0.0%, col4: 0.0%
# Shape: 117 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 34.2%, col3: 1.7%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.1%
# Zeros %: col1: 0.0%, col2: 84.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 48.8%, col3: 1.6%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.8%
# Zeros %: col1: 0.0%, col2: 63.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.1%, col3: 0.0%, col4: 0.0%
# Shape: 92 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 35.9%, col3: 0.0%, col4: 0.0%
# Shape: 126 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 68.3%, col3: 0.0%, col4: 7.1%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 3.6%, col3: 0.8%, col4: 0.0%
# Shape: 181 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.8%, col3: 0.0%, col4: 36.5%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 60.7%, col3: 0.0%, col4: 0.0%
# Shape: 145 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 52.8%, col3: 6.7%, col4: 0.0%
# Shape: 121 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 4.1%, col3: 0.0%, col4: 0.0%
# Shape: 146 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 55.2%, col3: 0.0%, col4: 0.0%
# Shape: 198 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 80.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 168 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 69.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 50.8%, col3: 4.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 54.8%, col3: 0.0%, col4: 0.0%
# Shape: 89 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.8%
# Zeros %: col1: 0.0%, col2: 85.4%, col3: 0.0%, col4: 0.0%
# Shape: 251 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 41.8%, col3: 0.0%, col4: 0.0%
# Shape: 181 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.8%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.8%
# Zeros %: col1: 0.0%, col2: 57.1%, col3: 0.0%, col4: 0.0%
# Shape: 102 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.3%
# Zeros %: col1: 0.0%, col2: 69.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.3%
# Zeros %: col1: 0.0%, col2: 86.9%, col3: 6.3%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 89.9%
# Zeros %: col1: 0.0%, col2: 39.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 95.2%
# Zeros %: col1: 0.0%, col2: 88.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 74.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 69.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.8%, col3: 0.0%, col4: 0.0%
# Shape: 227 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 95.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.3%
# Zeros %: col1: 0.0%, col2: 20.2%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 83.0%
# Zeros %: col1: 0.0%, col2: 42.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 73.8%, col3: 4.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 89.3%
# Zeros %: col1: 0.0%, col2: 94.4%, col3: 10.3%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 84.9%, col3: 0.0%, col4: 0.0%
# Shape: 182 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 33.5%, col3: 1.1%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 58.7%, col3: 2.8%, col4: 0.0%
# Shape: 178 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 67.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.1%
# Zeros %: col1: 0.0%, col2: 69.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 53.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 94.0%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 94.0%
# Zeros %: col1: 0.0%, col2: 92.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 37.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 74.2%, col3: 12.7%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 99.2%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.0%, col3: 0.0%, col4: 2.8%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.7%, col3: 0.0%, col4: 0.0%
# Shape: 189 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.2%, col3: 1.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 84.1%
# Zeros %: col1: 0.0%, col2: 3.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 83.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 71.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 4.8%, col3: 0.0%, col4: 0.0%
# Shape: 181 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 47.5%, col3: 2.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 32.5%, col3: 8.7%, col4: 0.0%
# Shape: 186 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.2%, col3: 0.0%, col4: 0.0%
# Shape: 97 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 91.8%
# Zeros %: col1: 0.0%, col2: 52.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 97.2%
# Zeros %: col1: 0.0%, col2: 93.3%, col3: 0.0%, col4: 0.0%
# Shape: 199 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 84.4%
# Zeros %: col1: 0.0%, col2: 74.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 76.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 23.8%, col3: 1.2%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 53.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 84.5%
# Zeros %: col1: 0.0%, col2: 54.0%, col3: 9.9%, col4: 0.0%
# Shape: 97 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 89.7%
# Zeros %: col1: 0.0%, col2: 36.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.1%
# Zeros %: col1: 0.0%, col2: 94.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 89.7%
# Zeros %: col1: 0.0%, col2: 66.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 20.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 42.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 17.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.8%, col3: 2.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 92.9%
# Zeros %: col1: 0.0%, col2: 79.8%, col3: 13.1%, col4: 0.0%
# Shape: 146 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 43.8%, col3: 0.0%, col4: 0.0%
# Shape: 89 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 4.5%, col3: 0.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.9%
# Zeros %: col1: 0.0%, col2: 43.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 31.3%, col3: 0.0%, col4: 0.0%
# Shape: 149 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 76.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 76.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.9%, col3: 4.8%, col4: 0.0%
# Shape: 236 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 25.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 42.1%
# Zeros %: col1: 0.0%, col2: 48.0%, col3: 44.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.3%
# Zeros %: col1: 0.0%, col2: 88.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 97.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 95.6%, col3: 0.4%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 21.4%, col3: 2.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.9%
# Zeros %: col1: 0.0%, col2: 68.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 94.8%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 78.0%, col3: 0.0%, col4: 0.0%
# Shape: 99 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 82.8%
# Zeros %: col1: 0.0%, col2: 56.6%, col3: 0.0%, col4: 0.0%
# Shape: 97 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 25.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 83.3%, col3: 0.0%, col4: 0.0%
# Shape: 108 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 9.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 84.5%, col3: 0.0%, col4: 0.0%
# Shape: 179 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 3.9%, col3: 0.0%, col4: 0.0%
# Shape: 251 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 60.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 63.9%, col3: 1.2%, col4: 0.0%
# Shape: 163 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.0%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.8%
# Zeros %: col1: 0.0%, col2: 44.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 93.3%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 83.0%
# Zeros %: col1: 0.0%, col2: 30.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.9%, col3: 0.0%, col4: 0.0%
# Shape: 199 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 83.9%
# Zeros %: col1: 0.0%, col2: 79.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 91.7%
# Zeros %: col1: 0.0%, col2: 94.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 13.5%, col3: 0.0%, col4: 0.0%
# Shape: 177 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.0%, col3: 0.0%, col4: 19.2%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 20.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.9%
# Zeros %: col1: 0.0%, col2: 93.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.9%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 32.9%, col3: 0.4%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 24.2%, col3: 1.6%, col4: 0.0%
# Shape: 250 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 84.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 67.1%, col3: 0.0%, col4: 0.0%
# Shape: 95 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 89.5%
# Zeros %: col1: 0.0%, col2: 35.8%, col3: 0.0%, col4: 0.0%
# Shape: 244 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 48.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 71.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 250 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 37.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.1%, col3: 0.0%, col4: 0.0%
# Shape: 250 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 78.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 50.4%, col3: 0.4%, col4: 0.0%
# Shape: 92 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 40.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 52.0%, col3: 0.4%, col4: 0.0%
# Shape: 146 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 50.7%, col3: 1.4%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 46.0%, col3: 1.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 39.7%, col3: 1.6%, col4: 0.0%
# Shape: 132 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 59.1%, col3: 0.0%, col4: 0.0%
# Shape: 157 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 80.3%
# Zeros %: col1: 0.0%, col2: 63.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 32.1%, col3: 0.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 83.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 24.2%, col3: 0.0%, col4: 0.0%
# Shape: 147 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 78.2%, col3: 0.0%, col4: 0.0%
# Shape: 237 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.7%, col3: 4.6%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.0%
# Zeros %: col1: 0.0%, col2: 51.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 17.5%, col3: 0.0%, col4: 0.0%
# Shape: 167 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 83.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 77.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.3%, col3: 2.8%, col4: 0.0%
# Shape: 108 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 89.8%
# Zeros %: col1: 0.0%, col2: 18.5%, col3: 0.0%, col4: 0.0%
# Shape: 180 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 71.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 83.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.9%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.7%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 75.0%, col3: 0.0%, col4: 0.0%
# Shape: 173 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 54.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.5%
# Zeros %: col1: 0.0%, col2: 88.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 83.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 55.2%, col3: 15.5%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.3%, col3: 0.0%, col4: 0.0%
# Shape: 115 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 68.7%
# Zeros %: col1: 0.0%, col2: 66.1%, col3: 1.7%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 56.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 69.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 42.1%, col3: 0.0%, col4: 0.0%
# Shape: 248 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 62.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 92.9%
# Zeros %: col1: 0.0%, col2: 95.6%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 83.0%
# Zeros %: col1: 0.0%, col2: 18.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 77.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 93.3%, col3: 0.0%, col4: 1.6%
# Shape: 243 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# ...
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.7%
# Zeros %: col1: 0.0%, col2: 72.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.5%, col3: 0.0%, col4: 0.0%
# Shape: 211 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 83.3%, col3: 0.0%, col4: 0.0%
# Shape: 96 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 76.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 75.0%, col3: 0.0%, col4: 0.0%
# Shape: 108 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 91.7%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.5%
# Zeros %: col1: 0.0%, col2: 80.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 78.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 61.9%, col3: 0.4%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.9%
# Zeros %: col1: 0.0%, col2: 92.9%, col3: 0.0%, col4: 0.0%
# Shape: 249 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 97 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.7%
# Zeros %: col1: 0.0%, col2: 14.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.1%
# Zeros %: col1: 0.0%, col2: 94.4%, col3: 0.0%, col4: 0.0%
# Shape: 188 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 85.6%, col3: 0.0%, col4: 0.0%
# Shape: 167 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 68.3%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.8%
# Zeros %: col1: 0.0%, col2: 61.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 40.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 57.9%, col3: 2.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 59.5%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 79.8%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 76.0%
# Zeros %: col1: 0.0%, col2: 12.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 89.3%, col3: 0.0%, col4: 0.0%
# Shape: 138 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 95.7%
# Zeros %: col1: 0.0%, col2: 89.1%, col3: 0.0%, col4: 0.0%
# Shape: 182 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 87.9%, col3: 0.0%, col4: 0.0%
# Shape: 139 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 93.7%, col3: 0.0%, col4: 0.0%
# Shape: 150 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 82.7%
# Zeros %: col1: 0.0%, col2: 96.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 50.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.1%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.1%, col3: 0.0%, col4: 0.0%
# Shape: 92 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 100.0%
# Zeros %: col1: 0.0%, col2: 66.3%, col3: 0.0%, col4: 0.0%
# Shape: 95 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 36.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.5%
# Zeros %: col1: 0.0%, col2: 73.0%, col3: 21.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 84.5%
# Zeros %: col1: 0.0%, col2: 47.2%, col3: 1.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 24.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 78.6%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 75.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.5%
# Zeros %: col1: 0.0%, col2: 86.1%, col3: 1.6%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 63.9%, col3: 5.2%, col4: 0.0%
# Shape: 164 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 82.9%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 93.0%
# Zeros %: col1: 0.0%, col2: 90.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 41.3%, col3: 0.0%, col4: 0.0%
# Shape: 250 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 84.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 85.7%
# Zeros %: col1: 0.0%, col2: 85.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 48.4%, col3: 0.0%, col4: 0.0%
# Shape: 146 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 5.5%, col3: 0.0%, col4: 0.0%
# Shape: 136 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 69.9%, col3: 0.0%, col4: 0.0%
# Shape: 206 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.3%, col3: 0.0%, col4: 0.0%
# Shape: 179 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 22.9%, col3: 0.0%, col4: 0.0%
# Shape: 96 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.5%
# Zeros %: col1: 0.0%, col2: 60.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 33.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 90.1%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.0%
# Zeros %: col1: 0.0%, col2: 71.0%, col3: 0.0%, col4: 0.0%
# Shape: 177 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 92.7%, col3: 0.0%, col4: 0.0%
# Shape: 195 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.2%, col3: 0.0%, col4: 0.0%
# Shape: 100 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 83.0%
# Zeros %: col1: 0.0%, col2: 55.0%, col3: 0.0%, col4: 0.0%
# Shape: 208 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 56.2%, col3: 0.0%, col4: 0.0%
# Shape: 200 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 65.0%, col3: 0.0%, col4: 0.0%
# Shape: 194 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 71.6%, col3: 1.0%, col4: 3.6%
# Shape: 179 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 78.8%, col3: 0.0%, col4: 0.0%
# Shape: 97 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 88.7%
# Zeros %: col1: 0.0%, col2: 32.0%, col3: 1.0%, col4: 1.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 69.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 90.9%
# Zeros %: col1: 0.0%, col2: 79.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.7%, col3: 0.0%, col4: 0.0%
# Shape: 250 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 66.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 58.7%, col3: 2.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 55.6%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 62.2%
# Zeros %: col1: 0.0%, col2: 8.2%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 91.3%, col3: 0.0%, col4: 0.0%
# Shape: 94 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.2%
# Zeros %: col1: 0.0%, col2: 64.9%, col3: 0.0%, col4: 0.0%
# Shape: 181 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 69.1%, col3: 0.0%, col4: 0.0%
# Shape: 98 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 86.7%
# Zeros %: col1: 0.0%, col2: 63.3%, col3: 0.0%, col4: 0.0%
# Shape: 97 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.6%
# Zeros %: col1: 0.0%, col2: 61.9%, col3: 0.0%, col4: 0.0%
# Shape: 183 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 15.8%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 84.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 51.6%, col3: 0.8%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.0%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 60.7%, col3: 0.0%, col4: 0.0%
# Shape: 96 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 87.5%
# Zeros %: col1: 0.0%, col2: 32.3%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 2.0%
# Zeros %: col1: 0.0%, col2: 34.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 93.7%
# Zeros %: col1: 0.0%, col2: 88.9%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 86.1%, col3: 0.0%, col4: 0.0%
# Shape: 96 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 84.4%
# Zeros %: col1: 0.0%, col2: 60.4%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 88.1%, col3: 0.0%, col4: 0.0%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 81.7%, col3: 0.0%, col4: 0.0%
# Shape: 171 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 78.9%, col3: 5.8%, col4: 0.6%
# Shape: 252 x 4
# Num Columns: 4, Num Numerical: 3, Num Textual: 1
# NULLs %: col1: 0.0%, col2: 0.0%, col3: 0.0%, col4: 0.0%
# Zeros %: col1: 0.0%, col2: 75.8%, col3: 0.0%, col4: 0.0%

# %%
# Counters
files_with_high_nulls = 0
files_with_high_zeros = 0
files_with_both = 0
total_files = 0

for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        total_files+=1
        file_path = os.path.join(csv_dir, file)
        df = pd.read_csv(file_path)

        # Compute % nulls and % zeros
        nulls = df.isnull().mean() * 100
        zeros = df.select_dtypes(include=np.number).eq(0).mean() * 100

        # Check conditions
        has_high_null = (nulls > 20).any()
        has_high_zero = (zeros > 20).any()

        if has_high_null:
            files_with_high_nulls += 1
        if has_high_zero:
            files_with_high_zeros += 1
        if has_high_null and has_high_zero:
            files_with_both += 1

print(f"Files with >20% NULLs in any column     : {files_with_high_nulls}")
print(f"Files with >20% ZEROs in any numeric col: {files_with_high_zeros}")
print(f"Files with BOTH >20% NULLs and ZEROs    : {files_with_both}")
# Out:
# Files with >20% NULLs in any column     : 1196
# Files with >20% ZEROs in any numeric col: 3790
# Files with BOTH >20% NULLs and ZEROs    : 1081

# %%
print(total_files)
# Out:
# 4110

# %%
import pandas as pd
import os
import numpy as np

csv_dir = "data/timeseries_data_dump/timeseries_data/"

summary_stats = []

for file in os.listdir(csv_dir):
    if file.endswith(".csv"):
        file_path = os.path.join(csv_dir, file)
        df = pd.read_csv(file_path)

        nulls_pct = df.isnull().mean() * 100
        zeros_pct = df.select_dtypes(include=np.number).eq(0).mean() * 100

        high_null_cols = nulls_pct[nulls_pct > 20].index.tolist()
        high_zero_cols = zeros_pct[zeros_pct > 20].index.tolist()

        has_high_nulls = len(high_null_cols) > 0
        has_high_zeros = len(high_zero_cols) > 0

        summary_stats.append({
            "File": file,
            "Has >20% NULLs?": has_high_nulls,
            "NULL Columns >20%": ", ".join(high_null_cols) if has_high_nulls else "None",
            "Has >20% ZEROs?": has_high_zeros,
            "ZERO Columns >20%": ", ".join(high_zero_cols) if has_high_zeros else "None",
            "Has Both?": has_high_nulls and has_high_zeros
        })

stats_df = pd.DataFrame(summary_stats)


for _, row in stats_df.iterrows():
    print(f"{row['File']}")
    if row["Has >20% NULLs?"]:
        print(f"NULL >20% columns : {row['NULL Columns >20%']}")
    if row["Has >20% ZEROs?"]:
        print(f"ZEROs >20% columns: {row['ZERO Columns >20%']}")
    if row["Has Both?"]:
        print("File has BOTH high NULLs and ZEROs")
    print("-" * 60)

# %% [markdown]
# ### Plots

# %%
folder_path = "data/timeseries_data_dump/timeseries_data/"

output_dir = os.path.join(folder_path, "plots")
os.makedirs(output_dir, exist_ok=True)

csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')][:10]

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    date_col = None
    for col in df.columns:
        try:
            parsed = pd.to_datetime(df[col], errors='raise')
            df[col] = parsed
            date_col = col
            break
        except:
            continue

    if date_col is None:
        print(f"{file} - No valid date column.")
        continue

    df = df.rename(columns={date_col: 'DATE'})
    df = df.sort_values(by='DATE')

    numeric_cols = df.select_dtypes(include=['number']).columns
    valid_cols = [col for col in numeric_cols if df[col].notna().any()]

    if not valid_cols:
        print(f"{file} - No valid numeric features.")
        continue

    n_features = len(valid_cols)
    total_rows = n_features + 1

    fig = plt.figure(figsize=(12, 3 * total_rows))
    gs = gridspec.GridSpec(total_rows, 1, hspace=0.5)

    ax_main = fig.add_subplot(gs[0])
    for col in valid_cols:
        ax_main.plot(df['DATE'], df[col], label=col)
    ax_main.set_title(f"{file} - Consolidated Plot")
    ax_main.set_xlabel("Date")
    ax_main.set_ylabel("Value")
    ax_main.legend()
    ax_main.grid(True)

    for i, col in enumerate(valid_cols):
        ax = fig.add_subplot(gs[i + 1])
        ax.plot(df['DATE'], df[col], color='tab:blue')
        ax.set_title(f"{col} vs Date")
        ax.set_xlabel("Date")
        ax.set_ylabel(col)
        ax.grid(True)

    plot_filename = os.path.join(output_dir, f"{os.path.splitext(file)[0]}_combined.png")
    plt.tight_layout()
    plt.savefig(plot_filename)
    plt.close()

    print(f"Saved combined plot: {plot_filename}")

# %% [markdown]
# ### Unwindowed dataset conversion
